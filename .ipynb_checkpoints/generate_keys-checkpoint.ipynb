# %%
import pickle
from pathlib import Path
import os

import streamlit_authenticator as stauth

names = ["CNZPD"]
usernames = ["CNZPD"]
passwords = ["Paris2024"]

hashed_passwords = stauth.Hasher(passwords).generate()

#file_path = 'C:\\Users\\samb\\CNZPD\\hashed_pw.pkl'
with open('C:\\Users\\samb\\CNZPD\\hashed_pw.pkl',"wb") as file:
    pickle.dump(hashed_passwords, file)
