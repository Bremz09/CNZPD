# %%
import pandas as pd
import openpyxl
import numpy as np
from __future__ import unicode_literals
from collections import defaultdict

from lxml import etree
from ranking import Ranking
import requests

from trueskill import Rating, rate_1vs1, quality_1vs1, rate, quality
from trueskill.mathematics import Gaussian

df = pd.read_excel(
        io='MensRaceResults.xlsm',
        engine ='openpyxl',
        sheet_name='Sprint',
        skiprows=0,
        usecols='A:T',
        nrows=3000
        )

# %%
df = df.replace({' ': '_'}, regex=True)
df = df.replace({'’': "'"}, regex=True)
df.insert(4, "Round", 1, True)

df_2 = df.loc[(df['Rank R2'] >0) ]
#df_2.insert(10, "Round", 2, True)
df_3 = df.loc[(df['Rank R3'] >0) ]
#df_3.insert(10, "Round", 3, True)

df_2["Round"] = 2
df_2["Rank R1"]=df_2["Rank R2"]
df_2["200m R1"]=df_2["200m R2"]

df_3["Round"] = 3
df_3["Rank R1"]=df_3["Rank R3"]
df_3["200m R1"]=df_3["200m R3"]

df_final = pd.concat([df,df_2,df_3])

df_final["Rank"] = df_final["Rank R1"]
df_final["Time"] = df_final["200m R1"]
df_final["Avg Speed"] = df_final["Avg Speed R1"]


df_final = df_final.drop(columns=['Rank R1', '200m R1', 'Avg Speed R1','Rank R2', '200m R2', 'Avg Speed R2','Rank R3', '200m R3', 'Avg Speed R3'])



df = df_final
df = df.reset_index()
df.insert(15,"Initial_CSE", "Holder", True)
df.insert(16,"Final_CSE", "Holder", True)
df.insert(17,"Mu", "Holder", True)
df.insert(18,"Sigma", "Holder", True)
df.insert(19,"ExpectedRank", "Holder", True)
df.insert(20,"RatingChange", "Holder", True)


df['Stage'] = pd.Categorical(df['Stage'], ["R32", "Rep32", "R16","Rep16","R8","Rep8","QF","5to8","SF","F"])

df=df.sort_values(["Date","Stage"])
df = df.reset_index()
df=df.drop(columns=["level_0","index"])

# %%
df
# Out:
#      Location  Year       Date Event  Round Stage Heat              Athlete  \
# 0      Milton  2018 2018-10-28    NC      1   R16    1        BARRETTE_Hugo
# 1      Milton  2018 2018-10-28    NC      1   R16    1       MITCHELL_Ethan
# 2      Milton  2018 2018-10-28    NC      1   R16    2        BAUGE_Gregory
# 3      Milton  2018 2018-10-28    NC      1   R16    2  MORENO_SANCHEZ_Jose
# 4      Milton  2018 2018-10-28    NC      1   R16    3        RUDYK_Mateusz
# ...       ...   ...        ...   ...    ...   ...  ...                  ...
# 1775    Cairo  2023 2023-03-17    NC      2     F    G     LAVREYSEN_Harrie
# 1776    Cairo  2023 2023-03-17    NC      2     F    G     YAKOVLEV_Mikhail
# 1777    Cairo  2023 2023-03-17    NC      2     F    B            OTA_Kaiya
# 1778    Cairo  2023 2023-03-17    NC      2     F    B        RUDYK_Mateusz
# 1779    Cairo  2023 2023-03-17    NC      2     F    G               Bremer
#
#      Country  Age  Final_Rank  Rank    Time  Avg Speed Initial_CSE Final_CSE  \
# 0        CAN  NaN        16.0   1.0  10.178        NaN      Holder    Holder
# 1        NZL  NaN        17.0   2.0  10.225        NaN      Holder    Holder
# 2        FRA  NaN         5.0   1.0  10.595        NaN      Holder    Holder
# 3        ESP  NaN        28.0   2.0  10.676        NaN      Holder    Holder
# 4        POL  NaN         9.0   1.0  10.204        NaN      Holder    Holder
# ...      ...  ...         ...   ...     ...        ...         ...       ...
# 1775     NED  NaN         1.0   1.0  10.019        NaN      Holder    Holder
# 1776     ISR  NaN         2.0   2.0  11.862        NaN      Holder    Holder
# 1777     JPN  NaN         3.0   1.0  10.364        NaN      Holder    Holder
# 1778     POL  NaN         4.0   2.0  10.481        NaN      Holder    Holder
# 1779     NED  NaN         1.0   1.0  10.019        NaN      Holder    Holder
#
#           Mu   Sigma ExpectedRank RatingChange
# 0     Holder  Holder       Holder       Holder
# 1     Holder  Holder       Holder       Holder
# 2     Holder  Holder       Holder       Holder
# 3     Holder  Holder       Holder       Holder
# 4     Holder  Holder       Holder       Holder
# ...      ...     ...          ...          ...
# 1775  Holder  Holder       Holder       Holder
# 1776  Holder  Holder       Holder       Holder
# 1777  Holder  Holder       Holder       Holder
# 1778  Holder  Holder       Holder       Holder
# 1779  Holder  Holder       Holder       Holder
#
# [1780 rows x 20 columns]

# %%
#Function for adding unique riders to array "rider"

def check_if_in_list(name):
    exists = name in rider
    if exists == False:
        a = (name)
        rider.append(str(a))
        
#implementing function

rider=[]
for i in range(len(df)):
    check_if_in_list(df.Athlete[i])
rider[0:5]



#Defining the Rider class which assigns the riders a name (their own) and a default skill

class Rider:
  def __init__(self, name, skill):
    self.skill = skill
    self.name = name
    
    def __lt__(self, other):
        return self.score < other.score
    
#Implementing function

for i in range(len(rider)):
    rider[i] = Rider(str(rider[i]), str(Rating()))
print(rider[5].skill)

#Defining the race function

skills=[]

def race(start):
    global skills
    j = start
    db = []
    starter = []
    rs = []
    order = []
    indexes = []
    rank = []
    word = "["
    while df.Rank[j] <= df.Rank[j+1]:
        index = next((k for k, item in enumerate(rider) if item.name == df.Athlete[j]), -1)
        indexes.append(index)
        rs.append('r'+str(j)) #maybe f strings?
        rank.append(int(df.Rank[j])-1)
        word = word + "(" + str(rider[index].skill).strip('trueskill.') + ",), "
        j+=1
    index = next((k for k, item in enumerate(rider) if item.name == df.Athlete[j]), -1)
    indexes.append(index)
    rs.append('r'+str(j))
    rank.append(int(df.Rank[j])-1)
    translation = {39: None}
    new = str(rs).translate(translation)
    word = word + "(" +str(rider[index].skill).strip('trueskill.') + ",)], ranks = " + str(rank) + ")"
    code_string = str(new) + " = rate(" + word
    exec(code_string)
    #print(rider[indexes[j]].skill+ "old")
    print(df.Location[j] + ' ' + df.Event[j] + ' ' + str(df.Stage[j]))
    for i in range(len(indexes)):
        x = str(eval(rs[i])).strip('(,)') + ')'
        rider[indexes[i]].skill=x
        skills.append(rider[indexes[i]].skill)
        
    start = j
    return start+1
    
    
#Looping through all races - The value counts thing is the number of first place finishes (not quite perfect)
#Just add a "stopper" race at the end
races = 0
start=0
events = int(df['Rank'].value_counts()[1])
for i in range(events+1):
    start = race(start)
    races +=1
# Out:
# trueskill.Rating(mu=25.000, sigma=8.333)
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC SF
# Milton NC SF
# Milton NC F
# Milton NC F
# Milton NC F
# Milton NC F
# Milton NC F
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R16
# Berlin NC R8
# Berlin NC R8
# Berlin NC R8
# Berlin NC R8
# Berlin NC R8
# Berlin NC R8
# Berlin NC R8
# Berlin NC R8
# Berlin NC QF
# Berlin NC QF
# Berlin NC QF
# Berlin NC QF
# Berlin NC QF
# Berlin NC QF
# Berlin NC QF
# Berlin NC QF
# Berlin NC SF
# Berlin NC SF
# Berlin NC SF
# Berlin NC SF
# Berlin NC F
# Berlin NC F
# Berlin NC F
# Berlin NC F
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R16
# London NC R8
# London NC R8
# London NC R8
# London NC R8
# London NC R8
# London NC R8
# London NC R8
# London NC R8
# London NC QF
# London NC QF
# London NC QF
# London NC QF
# London NC QF
# London NC QF
# London NC QF
# London NC SF
# London NC SF
# London NC SF
# London NC SF
# London NC SF
# London NC F
# London NC F
# London NC F
# London NC F
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC SF
# Cambridge NC SF
# Cambridge NC SF
# Cambridge NC SF
# Cambridge NC F
# Cambridge NC F
# Cambridge NC F
# Cambridge NC F
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC F
# Hong_Kong NC F
# Hong_Kong NC F
# Hong_Kong NC F
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R16
# Pruszkow WCH R8
# Pruszkow WCH R8
# Pruszkow WCH R8
# Pruszkow WCH R8
# Pruszkow WCH R8
# Pruszkow WCH R8
# Pruszkow WCH R8
# Pruszkow WCH R8
# Pruszkow WCH QF
# Pruszkow WCH QF
# Pruszkow WCH QF
# Pruszkow WCH QF
# Pruszkow WCH QF
# Pruszkow WCH QF
# Pruszkow WCH QF
# Pruszkow WCH QF
# Pruszkow WCH SF
# Pruszkow WCH SF
# Pruszkow WCH SF
# Pruszkow WCH SF
# Pruszkow WCH F
# Pruszkow WCH F
# Pruszkow WCH F
# Pruszkow WCH F
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R16
# Minsk NC R8
# Minsk NC R8
# Minsk NC R8
# Minsk NC R8
# Minsk NC R8
# Minsk NC R8
# Minsk NC R8
# Minsk NC R8
# Minsk NC QF
# Minsk NC QF
# Minsk NC QF
# Minsk NC QF
# Minsk NC QF
# Minsk NC QF
# Minsk NC QF
# Minsk NC QF
# Minsk NC SF
# Minsk NC SF
# Minsk NC SF
# Minsk NC F
# Minsk NC F
# Minsk NC F
# Minsk NC F
# Minsk NC F
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC SF
# Glasgow NC SF
# Glasgow NC SF
# Glasgow NC SF
# Glasgow NC F
# Glasgow NC F
# Glasgow NC F
# Glasgow NC F
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC F
# Hong_Kong NC F
# Hong_Kong NC F
# Hong_Kong NC F
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R16
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC R8
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC QF
# Cambridge NC SF
# Cambridge NC SF
# Cambridge NC SF
# Cambridge NC SF
# Cambridge NC F
# Cambridge NC F
# Cambridge NC F
# Cambridge NC F
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R16
# Brisbane NC R8
# Brisbane NC R8
# Brisbane NC R8
# Brisbane NC R8
# Brisbane NC R8
# Brisbane NC R8
# Brisbane NC R8
# Brisbane NC R8
# Brisbane NC QF
# Brisbane NC QF
# Brisbane NC QF
# Brisbane NC QF
# Brisbane NC QF
# Brisbane NC QF
# Brisbane NC QF
# Brisbane NC QF
# Brisbane NC SF
# Brisbane NC SF
# Brisbane NC SF
# Brisbane NC SF
# Brisbane NC F
# Brisbane NC F
# Brisbane NC F
# Brisbane NC F
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC SF
# Milton NC SF
# Milton NC SF
# Milton NC SF
# Milton NC SF
# Milton NC F
# Milton NC F
# Milton NC F
# Milton NC F
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R16
# Berlin WCH R8
# Berlin WCH R8
# Berlin WCH R8
# Berlin WCH R8
# Berlin WCH R8
# Berlin WCH R8
# Berlin WCH R8
# Berlin WCH R8
# Berlin WCH QF
# Berlin WCH QF
# Berlin WCH QF
# Berlin WCH QF
# Berlin WCH QF
# Berlin WCH QF
# Berlin WCH QF
# Berlin WCH QF
# Berlin WCH SF
# Berlin WCH SF
# Berlin WCH SF
# Berlin WCH SF
# Berlin WCH F
# Berlin WCH F
# Berlin WCH F
# Berlin WCH F
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R16
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC R8
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC QF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC SF
# Hong_Kong NC F
# Hong_Kong NC F
# Hong_Kong NC F
# Hong_Kong NC F
# St_Petersburg NC R16
# St_Petersburg NC R16
# St_Petersburg NC R16
# St_Petersburg NC R16
# St_Petersburg NC R16
# St_Petersburg NC R16
# St_Petersburg NC R16
# St_Petersburg NC R8
# St_Petersburg NC R8
# St_Petersburg NC R8
# St_Petersburg NC R8
# St_Petersburg NC R8
# St_Petersburg NC R8
# St_Petersburg NC R8
# St_Petersburg NC R8
# St_Petersburg NC QF
# St_Petersburg NC QF
# St_Petersburg NC QF
# St_Petersburg NC QF
# St_Petersburg NC QF
# St_Petersburg NC QF
# St_Petersburg NC QF
# St_Petersburg NC QF
# St_Petersburg NC SF
# St_Petersburg NC SF
# St_Petersburg NC SF
# St_Petersburg NC F
# St_Petersburg NC F
# St_Petersburg NC F
# St_Petersburg NC F
# St_Petersburg NC F
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY R32
# Tokyo OLY Rep32
# Tokyo OLY Rep32
# Tokyo OLY Rep32
# Tokyo OLY Rep32
# Tokyo OLY R16
# Tokyo OLY R16
# Tokyo OLY R16
# Tokyo OLY R16
# Tokyo OLY R16
# Tokyo OLY R16
# Tokyo OLY R16
# Tokyo OLY R16
# Tokyo OLY Rep16
# Tokyo OLY Rep16
# Tokyo OLY Rep16
# Tokyo OLY Rep16
# Tokyo OLY R8
# Tokyo OLY R8
# Tokyo OLY R8
# Tokyo OLY R8
# Tokyo OLY R8
# Tokyo OLY R8
# Tokyo OLY Rep8
# Tokyo OLY Rep8
# Tokyo OLY QF
# Tokyo OLY QF
# Tokyo OLY QF
# Tokyo OLY QF
# Tokyo OLY QF
# Tokyo OLY QF
# Tokyo OLY QF
# Tokyo OLY QF
# Tokyo OLY 5to8
# Tokyo OLY SF
# Tokyo OLY SF
# Tokyo OLY SF
# Tokyo OLY F
# Tokyo OLY F
# Tokyo OLY F
# Tokyo OLY F
# Tokyo OLY F
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC SF
# Cali NC SF
# Cali NC SF
# Cali NC SF
# Cali NC F
# Cali NC F
# Cali NC F
# Cali NC F
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R16
# Roubaix WCH R8
# Roubaix WCH R8
# Roubaix WCH R8
# Roubaix WCH R8
# Roubaix WCH R8
# Roubaix WCH R8
# Roubaix WCH R8
# Roubaix WCH R8
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH QF
# Roubaix WCH SF
# Roubaix WCH SF
# Roubaix WCH SF
# Roubaix WCH SF
# Roubaix WCH F
# Roubaix WCH F
# Roubaix WCH F
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R16
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC R8
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC QF
# Glasgow NC SF
# Glasgow NC SF
# Glasgow NC SF
# Glasgow NC F
# Glasgow NC F
# Glasgow NC F
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R16
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC R8
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC QF
# Milton NC SF
# Milton NC SF
# Milton NC SF
# Milton NC SF
# Milton NC F
# Milton NC F
# Milton NC F
# Milton NC F
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R16
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC R8
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC QF
# Cali NC SF
# Cali NC SF
# Cali NC SF
# Cali NC SF
# Cali NC F
# Cali NC F
# Cali NC F
# Cali NC F
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R16
# Paris WCH R8
# Paris WCH R8
# Paris WCH R8
# Paris WCH R8
# Paris WCH R8
# Paris WCH R8
# Paris WCH R8
# Paris WCH R8
# Paris WCH QF
# Paris WCH QF
# Paris WCH QF
# Paris WCH QF
# Paris WCH SF
# Paris WCH SF
# Paris WCH SF
# Paris WCH SF
# Paris WCH F
# Paris WCH F
# Paris WCH F
# Paris WCH F
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R16
# Jakarta NC R8
# Jakarta NC R8
# Jakarta NC R8
# Jakarta NC R8
# Jakarta NC R8
# Jakarta NC R8
# Jakarta NC R8
# Jakarta NC R8
# Jakarta NC QF
# Jakarta NC QF
# Jakarta NC QF
# Jakarta NC QF
# Jakarta NC QF
# Jakarta NC QF
# Jakarta NC QF
# Jakarta NC QF
# Jakarta NC SF
# Jakarta NC SF
# Jakarta NC SF
# Jakarta NC SF
# Jakarta NC F
# Jakarta NC F
# Jakarta NC F
# Jakarta NC F
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R16
# Cairo NC R8
# Cairo NC R8
# Cairo NC R8
# Cairo NC R8
# Cairo NC R8
# Cairo NC R8
# Cairo NC R8
# Cairo NC R8
# Cairo NC QF
# Cairo NC QF
# Cairo NC QF
# Cairo NC QF
# Cairo NC QF
# Cairo NC QF
# Cairo NC QF
# Cairo NC SF
# Cairo NC SF
# Cairo NC SF
# Cairo NC SF
# Cairo NC SF
# Cairo NC F
# Cairo NC F
# Cairo NC F
# Cairo NC F
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 1780 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [225], in <cell line: 80>()
#      79 events = int(df['Rank'].value_counts()[1])
#      80 for i in range(events+1):
# ---> 81     start = race(start)
#      82     races +=1
#
# Input In [225], in race(start)
#      46 rank = []
#      47 word = "["
# ---> 48 while df.Rank[j] <= df.Rank[j+1]:
#      49     index = next((k for k, item in enumerate(rider) if item.name == df.Athlete[j]), -1)
#      50     indexes.append(index)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 1780

# %%
#giving everyone a skill estimate of mu-2*sig AFTER their race

for i in range(len(skills)):
    skill_split = skills[i].split(',')
    mu = float(skill_split[0][20:])
    sigma = float(skill_split[1].split(')')[0][7:])
    xx = mu - 2*sigma
    df['Final_CSE'][i] = xx
    df['Mu'][i] = mu
    df['Sigma'][i] = sigma
    
#Initial Rating. "Spots" is a list of all indexes where that athlete appears. 

for i in range(len(df)):
    name = df['Athlete'][i]
    spots = df.index[df['Athlete'] == name].tolist()
    #print(name)
    #print(spots)
    if i == spots[0]:
        df.Initial_CSE[i] = 9.00 #assigns baseline skill if this is there first appearance 
    else:
        spot_index = spots.index(i)
        df.Initial_CSE[i] = df.Final_CSE[spots[spot_index-1]] #assigns most recent "final_CSE" if they've appeared before
    #df.RatingChange[i] = df.Final_CSE[i] - df.Initial_CSE[i]
    
#This is for the expected rank. It creates a df for each heat, sorts it, then creates the "expected" array which is the 
#expected ranks. It may go [1,2,3,3,3,6] for example

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None
#warnings.filterwarnings(action='once')
i=0
while i <= len(df):
    df_temp = pd.DataFrame(columns = ["Athlete", "Initial_CSE","Index"])
    while df.Rank[i]<df.Rank[i+1]:
        df_temp=df_temp.append({'Athlete' : df.Athlete[i], 'Initial_CSE' : df.Initial_CSE[i], 'Index' : i}, ignore_index=True)
        i+=1
    df_temp=df_temp.append({'Athlete' : df.Athlete[i], 'Initial_CSE' : df.Initial_CSE[i], 'Index' : i}, ignore_index=True)
    i+=1
    df_temp = df_temp.sort_values(by = "Initial_CSE", ascending=False)
    df_temp = df_temp.reset_index(drop=True)
    expected =[1]
    for j in range(1,len(df_temp)):
        if df_temp.Initial_CSE[j] == df_temp.Initial_CSE[j-1]:
            #print("same" + str(df_temp.Initial_CSE[j]))
            expectation = expected[j-1]
            expected.append(expectation)
        else:
            expectation = len(expected) +1 
            expected.append(expectation)
    #print(df_temp)
    #print(expected)
    for k in range(len(expected)):
        index = df_temp.Index[k]
        df.ExpectedRank[index] = expected[k]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 1780 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [226], in <cell line: 34>()
#      34 while i <= len(df):
#      35     df_temp = pd.DataFrame(columns = ["Athlete", "Initial_CSE","Index"])
# ---> 36     while df.Rank[i]<df.Rank[i+1]:
#      37         df_temp=df_temp.append({'Athlete' : df.Athlete[i], 'Initial_CSE' : df.Initial_CSE[i], 'Index' : i}, ignore_index=True)
#      38         i+=1
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 1780

# %%
df.to_csv(r'Sprint_Trueskill_Men.csv',index=False)

# %%
df.to_csv(r'Sprint_Trueskill_Men_order_check_2.csv',index=False)

# %%
df
# Out:
#      Location  Year       Date Event  Round Stage Heat              Athlete  \
# 0      Milton  2018 2018-10-28    NC      1   R16    1        BARRETTE_Hugo
# 1      Milton  2018 2018-10-28    NC      1   R16    1       MITCHELL_Ethan
# 2      Milton  2018 2018-10-28    NC      1   R16    2        BAUGE_Gregory
# 3      Milton  2018 2018-10-28    NC      1   R16    2  MORENO_SANCHEZ_Jose
# 4      Milton  2018 2018-10-28    NC      1   R16    3        RUDYK_Mateusz
# ...       ...   ...        ...   ...    ...   ...  ...                  ...
# 1775    Cairo  2023 2023-03-17    NC      2     F    G     LAVREYSEN_Harrie
# 1776    Cairo  2023 2023-03-17    NC      2     F    G     YAKOVLEV_Mikhail
# 1777    Cairo  2023 2023-03-17    NC      2     F    B            OTA_Kaiya
# 1778    Cairo  2023 2023-03-17    NC      2     F    B        RUDYK_Mateusz
# 1779    Cairo  2023 2023-03-17    NC      2     F    G               Bremer
#
#      Country  Age  Final_Rank  Rank    Time  Avg Speed Initial_CSE Final_CSE  \
# 0        CAN  NaN        16.0   1.0  10.178        NaN         9.0    15.054
# 1        NZL  NaN        17.0   2.0  10.225        NaN         9.0     6.262
# 2        FRA  NaN         5.0   1.0  10.595        NaN         9.0    15.054
# 3        ESP  NaN        28.0   2.0  10.676        NaN         9.0     6.262
# 4        POL  NaN         9.0   1.0  10.204        NaN         9.0    15.054
# ...      ...  ...         ...   ...     ...        ...         ...       ...
# 1775     NED  NaN         1.0   1.0  10.019        NaN      39.668    39.615
# 1776     ISR  NaN         2.0   2.0  11.862        NaN      32.983    32.619
# 1777     JPN  NaN         3.0   1.0  10.364        NaN      33.411     33.82
# 1778     POL  NaN         4.0   2.0  10.481        NaN      31.857    31.782
# 1779     NED  NaN         1.0   1.0  10.019        NaN      28.228    Holder
#
#           Mu   Sigma ExpectedRank RatingChange
# 0     29.396   7.171            1       Holder
# 1     20.604   7.171            1       Holder
# 2     29.396   7.171            1       Holder
# 3     20.604   7.171            1       Holder
# 4     29.396   7.171            1       Holder
# ...      ...     ...          ...          ...
# 1775  41.707   1.046            1       Holder
# 1776  36.687   2.034            2       Holder
# 1777  37.554   1.867            1       Holder
# 1778  33.682    0.95            2       Holder
# 1779  Holder  Holder       Holder       Holder
#
# [1780 rows x 20 columns]
